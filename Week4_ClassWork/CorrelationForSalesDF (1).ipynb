# %%
import pandas as pd
import seaborn as sns
import matplotlib as plt

# %%
df_sales =  pd.read_csv('sample_sales_data.csv')
df_sales
# Out:
#     OrderID CustomerName     Category  OrderDate  Quantity   Price  \
# 0   ORD0001       Hannah        Books   1/1/2025         6  331.73
# 1   ORD0002       Edward        Books   1/2/2025         3  310.03
# 2   ORD0003        Alice     Clothing   1/3/2025         9  176.17
# 3   ORD0004       Hannah  Electronics   1/4/2025         3   79.97
# 4   ORD0005       George         Home   1/5/2025         7  406.03
# ..      ...          ...          ...        ...       ...     ...
# 95  ORD0096        Diana     Clothing   4/6/2025         5  368.23
# 96  ORD0097          Bob        Books   4/7/2025         8  360.17
# 97  ORD0098        Diana     Clothing   4/8/2025         9   29.97
# 98  ORD0099        Alice         Home   4/9/2025         5  465.20
# 99  ORD0100      Charlie        Books  4/10/2025         9   41.55
#
#     TotalAmount     Status
# 0       1990.38   Canceled
# 1        930.09  Completed
# 2       1585.53   Canceled
# 3        239.91    Pending
# ...

# %%
df_sales.isna().sum()
Num_DF = df_sales.select_dtypes(include='number')

# %%
Num_DF
# Out:
#     Quantity   Price  TotalAmount
# 0          6  331.73      1990.38
# 1          3  310.03       930.09
# 2          9  176.17      1585.53
# 3          3   79.97       239.91
# 4          7  406.03      2842.21
# ..       ...     ...          ...
# 95         5  368.23      1841.15
# 96         8  360.17      2881.36
# 97         9   29.97       269.73
# 98         5  465.20      2326.00
# 99         9   41.55       373.95
#
# [100 rows x 3 columns]

# %%
sns.heatmap(Num_DF.corr())
# Out:
# <Axes: >

# %%
sns.scatterplot(data=Num_DF, x='Price', y='TotalAmount') \
    .set(title="Scatter Plot: Quantity vs Total Amount")
# Out:
# [Text(0.5, 1.0, 'Scatter Plot: Quantity vs Total Amount')]

# %%
sns.scatterplot(data=Num_DF, x='Quantity', y='TotalAmount') \
    .set(title="Scatter Plot: Quantity vs Total Amount")
# Out:
# [Text(0.5, 1.0, 'Scatter Plot: Quantity vs Total Amount')]

# %%
sns.scatterplot(data=Num_DF, x='Quantity', y='Price') \
    .set(title="Scatter Plot: Quantity vs Total Amount")
# Out:
# [Text(0.5, 1.0, 'Scatter Plot: Quantity vs Total Amount')]

# %%
sns.barplot(data=df_sales, x='Category', y='TotalAmount', estimator=sum,ci=None)
# Out:
# <ipython-input-78-9a0c7960e0b4>:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(data=df_sales, x='Category', y='TotalAmount', estimator=sum,ci=None)
# <Axes: xlabel='Category', ylabel='TotalAmount'>

# %%
sns.boxplot(data=df_sales, x='Category', y='TotalAmount')
# Out:
# <Axes: xlabel='Category', ylabel='TotalAmount'>

# %%
import matplotlib.pyplot as plt

# %%
fig, axes = plt.subplots(1, 2, figsize=(15, 6))

# Plot the correlation heatmap on the first subplot
sns.heatmap(Num_DF, cmap='coolwarm', ax=axes[0])
axes[0].set_title('Correlation Matrix')

# Plot scatter plots on the second subplot
sns.scatterplot(data=Num_DF, x='Quantity', y='TotalAmount', ax=axes[1], color='blue', label='Quantity vs TotalAmount')
sns.scatterplot(data=Num_DF, x='Price', y='TotalAmount', ax=axes[1], color='red', label='Price vs TotalAmount')

axes[1].set_title('Scatter Plots')
axes[1].legend()

# Adjust layout for better spacing
plt.tight_layout()

# Show the plot
plt.show()
